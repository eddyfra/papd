# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl

# %%
datos = pd.read_excel("dataset-servicios.xlsx")

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33459 entries, 0 to 33458
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   num_exp    33459 non-null  int64
#  1   cod_est    33459 non-null  object
#  2   cod_cli    26529 non-null  object
#  3   num_pol    33459 non-null  object
#  4   locali     26685 non-null  object
#  5   cod_com    33459 non-null  int64
#  6   nom_com    33459 non-null  object
#  7   cod_enc    33459 non-null  object
#  8   per_aut    1475 non-null   object
#  9   cti_pro_a  33455 non-null  float64
#  10  tit_pol    33455 non-null  object
#  11  ben_ser    33454 non-null  object
#  12  lug_asi    33454 non-null  object
#  13  num_lin    33459 non-null  object
#  14  cod_pro    33459 non-null  int64
#  15  nom_pro    33459 non-null  object
#  16  mes        33459 non-null  object
#  17  fec_ser    33459 non-null  object
#  18  hor_ser    33459 non-null  object
#  19  cod_zon    32132 non-null  float64
#  20  cod_pre    33459 non-null  int64
#  21  des_pre    33459 non-null  object
#  22  cod_dep    33459 non-null  int64
#  23  nom_dep    33459 non-null  object
#  24  cti_pro_b  33459 non-null  int64
#  25  nti_pro    33459 non-null  object
#  26  estimado   33459 non-null  float64
#  27  Sin IVA    33459 non-null  float64
#  28  xcontacto  33459 non-null  int64
#  29  let_tip    33459 non-null  object
#  30  let_cat    33459 non-null  object
#  31  cod_are    33459 non-null  object
#  32  fechor     33459 non-null  object
#  33  marca      30816 non-null  object
#  34  color      30314 non-null  object
#  35  año        29104 non-null  float64
#  36  placa      30771 non-null  object
#  37  inciso     25993 non-null  float64
#  38  tel_cas    205 non-null    float64
#  39  tel_ofi    3928 non-null   float64
#  40  cel_con    33450 non-null  object
#  41  num        33459 non-null  int64
# dtypes: float64(8), int64(8), object(26)
# memory usage: 10.7+ MB

# %% [markdown]
# ### ANALISIS EXPLORATORIO

# %%
datos
# Out:
#         num_exp cod_est cod_cli     num_pol  locali  cod_com  \
# 0      20000001       C      61      980755  ASISTO        2
# 1      20000004       C       1        3035    ASME        2
# 2      20000007       C      61       41356  ASISTO        2
# 3      20000015       C     NaN  AUTORIZADO     NaN        2
# 4      20000019       C      61      975636  ASISTO        2
# ...         ...     ...     ...         ...     ...      ...
# 33454  29009367       C     NaN  AUTORIZADO     NaN        2
# 33455  29009367       C     NaN  AUTORIZADO     NaN        2
# 33456  29009514       C     NaN  AUTORIZADO     NaN        2
# 33457  29009514       C     NaN  AUTORIZADO     NaN        2
# 33458  29009557       C      61      976929  ASISTO        2
#
#                       nom_com cod_enc per_aut  cti_pro_a  ...  \
# 0      SEGUROS EL ROBLE, S.A.     BVB     NaN        1.0  ...
# 1      SEGUROS EL ROBLE, S.A.     JSR     NaN        3.0  ...
# 2      SEGUROS EL ROBLE, S.A.     BVB     NaN        1.0  ...
# 3      SEGUROS EL ROBLE, S.A.     DQG     NaN        3.0  ...
# 4      SEGUROS EL ROBLE, S.A.     DVR     NaN        5.0  ...
# ...                       ...     ...     ...        ...  ...
# 33454  SEGUROS EL ROBLE, S.A.     AEG     NaN        5.0  ...
# 33455  SEGUROS EL ROBLE, S.A.     AEG     NaN        5.0  ...
# 33456  SEGUROS EL ROBLE, S.A.     AVT     NaN        4.0  ...
# 33457  SEGUROS EL ROBLE, S.A.     AVT     NaN        4.0  ...
# 33458  SEGUROS EL ROBLE, S.A.     LFC     NaN        1.0  ...
#
#                    fechor                 marca     color     año     placa  \
# 0      01-Jan-10 00:19:36              BMW 320I  PLATEADO  2006.0  P-724BHS
# 1      01-Jan-10 01:20:01                   NaN       NaN     NaN       NaN
# 2      01-Jan-10 03:03:48               COROLLA     BEIGE  2003.0  P-988DBL
# 3      01-Jan-10 07:52:27                   NaN       NaN     NaN       NaN
# 4      01-Jan-10 09:54:38  HYUNDAI SANTA FE GLS   CELESTE  2008.0  P-892DLY
# ...                   ...                   ...       ...     ...       ...
# 33454  04-Jan-10 12:45:27          TOYOTA HILUX     BEIGE  2009.0    108DTY
# 33455  04-Jan-10 12:46:32          TOYOTA HILUX     BEIGE  2009.0    108DTY
# 33456  19-Jan-10 12:26:30  AGUA PURA SALVAVIDAS       NaN     NaN     N1574
# 33457  19-Jan-10 12:35:25  AGUA PURA SALVAVIDAS       NaN     NaN     N1574
# 33458  01-Jan-10 13:11:52             CHERRY QQ  PLATEADO  2009.0  P-295DNT
#
#       inciso tel_cas     tel_ofi     cel_con   num
# 0        1.0     NaN         NaN    55106421     1
# 1        NaN     NaN         NaN    57026077     4
# 2        1.0     NaN         NaN    57032910     7
# 3        NaN     NaN         NaN    52073868    15
# 4        1.0     NaN         NaN  5024218588    19
# ...      ...     ...         ...         ...   ...
# 33454    NaN     NaN         NaN    57606578  9367
# 33455    NaN     NaN         NaN    57606578  9367
# 33456    NaN     NaN  41012322.0    50458175  9514
# 33457    NaN     NaN  41012322.0    50458175  9514
# 33458    1.0     NaN         NaN    54781759  9557
#
# [33459 rows x 42 columns]

# %%
datos('cod_com')[['cti_pro_a']].plot(kind='bar',rot=65,figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\David\OneDrive - Universidad Galileo\Mestría de BI\Postgrado en Análisi y Prediccion de Datos\2do Trimestre\Statistical Learning\Proyecto Final\1. Análisis exploratorio.ipynb Celda 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/David/OneDrive%20-%20Universidad%20Galileo/Mestr%C3%ADa%20de%20BI/Postgrado%20en%20An%C3%A1lisi%20y%20Prediccion%20de%20Datos/2do%20Trimestre/Statistical%20Learning/Proyecto%20Final/1.%20An%C3%A1lisis%20exploratorio.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> datos('cod_com')[['cti_pro_a']].plot(kind='bar',rot=65,figsize=(20,10))
#
# TypeError: 'DataFrame' object is not callable

# %%
fig = plt.figure()
ax=fig.add_subplot(111)

datos['Age'].plot.density(color='red', label='Original')
datos['Age_Mean'].plot.density(color='blue', label='Media')
datos['Age_Median'].plot.density(color='green', label='Median')
ax.legend()

# %%
media = datos['GOALS_HOME'].mean()
mediana = datos['GOALS_HOME'].median()

print(f"media: {media}")
print(f"Mediana: {mediana}")
# Out:
# media: 1.3943355119825709
# Mediana: 1.0

# %%
datos['GOALS_HOME_MEAN']= np.round(datos['GOALS_HOME'].fillna(media),0)
datos['GOALS_HOME_MEDIAN']= np.round(datos['GOALS_HOME'].fillna(mediana),0)

# %%
fig = plt.figure()
ax=fig.add_subplot(111)

datos['GOALS_HOME'].plot.density(color='red', label='Original')
datos['GOALS_HOME_MEAN'].plot.density(color='blue', label='Media')
datos['GOALS_HOME_MEDIAN'].plot.density(color='green', label='Median')
ax.legend()

# %%
datos[['GOALS_HOME', 'GOALS_HOME_MEAN', 'GOALS_HOME_MEDIAN']].boxplot()
plt.show()
